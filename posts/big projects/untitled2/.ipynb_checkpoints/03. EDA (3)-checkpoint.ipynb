# %% [raw]
# ---
# title : "03. EDA (3)"
# author : "GC"
# date : "06/19/24"
# ---

# %%
import pandas as pd
import os
import plotly.express as px
import plotly.io as pio

import matplotlib as mpl
import seaborn as sns 
mpl.rc('font', family='Malgun Gothic')
pd.set_option('display.float_format', lambda x: '{:.0f}'.format(x))

pio.renderers.default = "plotly_mimetype+notebook_connected"
import warnings

warnings.filterwarnings(action = "ignore")

# %%
#df1 = pd.read_csv('CI_LSR_CLTUR_LCLAS_TY_ACCTO_EXPR_AT_INFO_202405.csv')
file_list = os.listdir("C:/Users/user/Desktop/competition/data2")
len(file_list)
# Out:
# 130

# %% [markdown]
# 20211103 - 20240529 여가문화 유형별 관심도 data

# %%
data = pd.DataFrame()
for i in range(len(file_list)) :
    temp = pd.read_csv("data2/"+file_list[i])
    data = pd.concat([data,temp])

# %%
data.reset_index(inplace=True,drop = True)

# %%
data
# Out:
#        RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0             434         20211103               M           50대
# 1            1207         20211103               M           50대
# 2            2813         20211103               M           60대
# 3            5144         20211103               F           50대
# 4            5986         20211103               M           60대
# ...           ...              ...             ...           ...
# 68543    53376819         20240529               M           50대
# 68544    53376852         20240529               M           60대
# 68545    53377009         20240529               F           50대
# 68546    53377021         20240529               M           30대
# 68547    53377478         20240529               F           60대
#
#       ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                 서울특별시              700만원 이상
# 1                   경기도         300이상500만원 미만
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68548 entries, 0 to 68547
# Data columns (total 14 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   RESPOND_ID                                68548 non-null  int64
#  1   EXAMIN_BEGIN_DE                           68548 non-null  int64
#  2   SEXDSTN_FLAG_CD                           68548 non-null  object
#  3   AGRDE_FLAG_NM                             68548 non-null  object
#  4   ANSWRR_OC_AREA_NM                         68548 non-null  object
#  5   HSHLD_INCOME_DGREE_NM                     68548 non-null  object
#  6   CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE       68548 non-null  object
#  7   CLTUR_ART_ACT_INTRST_DGREE_VALUE          68548 non-null  object
#  8   SPORTS_VIEWNG_INTRST_DGREE_VALUE          68548 non-null  object
#  9   SPORTS_ACT_INTRST_DGREE_VALUE             68548 non-null  object
# ...

# %%
len(data.RESPOND_ID.unique())
# Out:
# 32507

# %%
data.RESPOND_ID.value_counts()
# Out:
# RESPOND_ID
# 53330089    11
# 53349523    11
# 53346303    10
# 53363542    10
# 53357060    10
#             ..
# 114579       1
# 113122       1
# 111195       1
# 108453       1
# 53372677     1
# Name: count, Length: 32507, dtype: int64

# %%
data.loc[data.RESPOND_ID == 53330089]
# Out:
#        RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 9806     53330089         20220309               M           20대
# 17491    53330089         20220629               M           20대
# 24863    53330089         20221005               M           20대
# 31714    53330089         20230104               M           20대
# 38589    53330089         20230405               M           20대
# 39650    53330089         20230419               M           20대
# 41760    53330089         20230517               M           20대
# 45967    53330089         20230712               M           20대
# 53368    53330089         20231018               M           20대
# 60781    53330089         20240124               M           20대
# 67605    53330089         20240522               M           20대
#
#       ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 9806               충청북도              700만원 이상
# 17491              충청북도         500이상700만원 미만
# ...

# %%
data['ID_DATE'] = data['RESPOND_ID'].astype(str) + '_' + data['EXAMIN_BEGIN_DE'].astype(str)

# %%
data
# Out:
#        RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0             434         20211103               M           50대
# 1            1207         20211103               M           50대
# 2            2813         20211103               M           60대
# 3            5144         20211103               F           50대
# 4            5986         20211103               M           60대
# ...           ...              ...             ...           ...
# 68543    53376819         20240529               M           50대
# 68544    53376852         20240529               M           60대
# 68545    53377009         20240529               F           50대
# 68546    53377021         20240529               M           30대
# 68547    53377478         20240529               F           60대
#
#       ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                 서울특별시              700만원 이상
# 1                   경기도         300이상500만원 미만
# ...

# %%
data.ID_DATE.value_counts()
# Out:
# ID_DATE
# 434_20211103         1
# 53355277_20230705    1
# 53353925_20230705    1
# 53353939_20230705    1
# 53353974_20230705    1
#                     ..
# 53338138_20220907    1
# 53338391_20220907    1
# 53338543_20220907    1
# 53338733_20220907    1
# 53377478_20240529    1
# Name: count, Length: 68548, dtype: int64

# %%
data.drop_duplicates(subset='ID_DATE', keep='first', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68548 entries, 0 to 68547
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   RESPOND_ID                                68548 non-null  int64
#  1   EXAMIN_BEGIN_DE                           68548 non-null  int64
#  2   SEXDSTN_FLAG_CD                           68548 non-null  object
#  3   AGRDE_FLAG_NM                             68548 non-null  object
#  4   ANSWRR_OC_AREA_NM                         68548 non-null  object
#  5   HSHLD_INCOME_DGREE_NM                     68548 non-null  object
#  6   CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE       68548 non-null  object
#  7   CLTUR_ART_ACT_INTRST_DGREE_VALUE          68548 non-null  object
#  8   SPORTS_VIEWNG_INTRST_DGREE_VALUE          68548 non-null  object
#  9   SPORTS_ACT_INTRST_DGREE_VALUE             68548 non-null  object
# ...

# %%
data.rename(columns={'ID_DATE':'key'}, inplace=True)

# %%
data
# Out:
#        RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0             434         20211103               M           50대
# 1            1207         20211103               M           50대
# 2            2813         20211103               M           60대
# 3            5144         20211103               F           50대
# 4            5986         20211103               M           60대
# ...           ...              ...             ...           ...
# 68543    53376819         20240529               M           50대
# 68544    53376852         20240529               M           60대
# 68545    53377009         20240529               F           50대
# 68546    53377021         20240529               M           30대
# 68547    53377478         20240529               F           60대
#
#       ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                 서울특별시              700만원 이상
# 1                   경기도         300이상500만원 미만
# ...

# %%
data.to_csv('dataset2(key값).csv', index=False)

# %%
data = data.sort_values(by='EXAMIN_BEGIN_DE', ascending=True)
data
# Out:
#        RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0             434         20211103               M           50대
# 719      50269108         20211103               F           50대
# 720      50269615         20211103               F           20대
# 721      50269863         20211103               F           20대
# 722      50271549         20211103               F           20대
# ...           ...              ...             ...           ...
# 68190    53338767         20240529               M           50대
# 68189    53338752         20240529               M           20대
# 68188    53338665         20240529               F           60대
# 68186    53338596         20240529               F           40대
# 68547    53377478         20240529               F           60대
#
#       ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                 서울특별시              700만원 이상
# 719                충청남도         500이상700만원 미만
# ...

# %%
data['EXAMIN_BEGIN_DE'] = pd.to_datetime(data['EXAMIN_BEGIN_DE'], format='%Y%m%d')

# %%
data.isnull().sum()
# Out:
# RESPOND_ID                                  0
# EXAMIN_BEGIN_DE                             0
# SEXDSTN_FLAG_CD                             0
# AGRDE_FLAG_NM                               0
# ANSWRR_OC_AREA_NM                           0
# HSHLD_INCOME_DGREE_NM                       0
# CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE         0
# CLTUR_ART_ACT_INTRST_DGREE_VALUE            0
# SPORTS_VIEWNG_INTRST_DGREE_VALUE            0
# SPORTS_ACT_INTRST_DGREE_VALUE               0
# TURSM_TOUR_INTRST_DGREE_VALUE               0
# RCRT_REST_INTRST_DGREE_VALUE                0
# SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE    0
# SCT_EXCHG_INTRST_DGREE_VALUE                0
# key                                         0
# dtype: int64

# %%
data['ANSWRR_OC_AREA_NM'].unique()
# Out:
# array(['서울특별시', '충청남도', '광주광역시', '대전광역시', '경상남도', '경상북도', '부산광역시', '충청북도',
#        '경기도', '대구광역시', '전라북도', '전라남도', '세종특별자치시', '울산광역시', '인천광역시', '강원도',
#        '제주특별자치도'], dtype=object)

# %%
data["ANSWRR_OC_AREA_NM"].value_counts()
# Out:
# ANSWRR_OC_AREA_NM
# 경기도        16241
# 서울특별시      12525
# 부산광역시       5027
# 경상남도        4407
# 인천광역시       4352
# 경상북도        3373
# 대구광역시       3289
# 충청남도        2714
# 충청북도        2440
# 대전광역시       2293
# 전라북도        2241
# 광주광역시       2201
# 전라남도        2169
# 강원도         2060
# 울산광역시       1698
# 제주특별자치도      909
# 세종특별자치시      609
# Name: count, dtype: int64

# %%
data["HSHLD_INCOME_DGREE_NM"].value_counts()
# Out:
# HSHLD_INCOME_DGREE_NM
# 300이상500만원 미만    20202
# 300만원 미만         16576
# 700만원 이상         13959
# 500이상700만원 미만    13543
# 무응답               4268
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path='C:\Windows\Fonts\malgun.ttf'
font_name=fm.FontProperties(fname=font_path).get_name()

# %%
data['ANSWRR_OC_AREA_NM'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
data['AGRDE_FLAG_NM'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#문화예술관람관심정도값
data['CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#문화예술활동관심정도값
data['CLTUR_ART_ACT_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#스포츠관람관심정도값
data['SPORTS_VIEWNG_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#스포츠활동관심정도값
data['SPORTS_ACT_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#관광여행관심정도값
data['TURSM_TOUR_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#오락휴식관심정도값
data['RCRT_REST_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#본인계발본인관리관심정도값
data['SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %%
#사회교류관심정도값
data['SCT_EXCHG_INTRST_DGREE_VALUE'].value_counts().plot.pie(autopct='%1.1f%%')
plt.rc('font',family=font_name)

# %% [markdown]
# 성별
# 연령대
# 답변자거주지역(도단위)
# 가구소득정도
# 조사 일자에 따라
# 관심도 파악 가능
